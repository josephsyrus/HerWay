# %% [markdown]
# # HerWay: Safest Route Finder using A* Algorithm
#
# This notebook implements the A* search algorithm to find the **safest possible route** between two locations. The path is determined by finding the sequence of areas that results in the lowest cumulative 'danger score'.
#
# **A* Implementation (`f(n) = g(n) + h(n)`):**
# - **`g(n)` (Cost to Reach):** The cumulative **danger score** from the start to the current node `n`. The algorithm's primary goal is to minimize this value.
# - **`h(n)` (Heuristic):** The straight-line geographical distance. This acts as a guide to ensure the algorithm finds an efficient path among equally safe options.
#
# **Key Features:**
# 1.  **Safety-First Pathfinding:** The algorithm is hardcoded to always prioritize the path with the minimum total danger score.
# 2.  **Data-Driven Danger Score:** A `danger_score` is calculated for each area based on crime counts and streetlight quality.
# 3.  **Hop-by-Hop Visualization:** The final route is plotted on a `folium` map, showing all the intermediate areas (hops) from the start to the destination.

# %% [markdown]
# ## 1. Setup and Library Installation

# %%
# !pip install pandas geopy folium networkx ipywidgets openpyxl
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (2.4.1)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (0.20.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (3.5)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (7.7.1)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy) (2.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from folium) (0.8.1)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.12/dist-packages (from folium) (3.1.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from folium) (2.32.4)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from folium) (2025.4.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets) (3.0.15)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.1.12)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (0.1.7)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (1.6.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (25.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets) (6.4.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets) (4.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=2.9->folium) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets) (6.5.7)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->folium) (2025.8.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets) (0.8.4)
# Requirement already satisfied: jupyter-core>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (5.8.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (5.10.4)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (7.16.6)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.22.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets) (0.2.13)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core>=4.6.0->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets) (4.3.8)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (3.1.3)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.12/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.25.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.4.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (0.27.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.12/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.14.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (2.22)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (4.10.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets) (1.3.1)

# %% [markdown]
# ## 2. Importing Libraries

# %%
import pandas as pd
import numpy as np
import folium
import networkx as nx
import heapq
import time
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut, GeocoderUnavailable
from math import radians, sin, cos, sqrt, atan2
import ipywidgets as widgets
from IPython.display import display, clear_output
import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 3. Data Loading and Preprocessing
#
# **Instructions:**
# 1.  Click on the folder icon in the left sidebar.
# 2.  Click on the 'Upload to session storage' button.
# 3.  Select the `HerWay_final_dataset.xlsx` file.

# %%
excel_file_path = 'HerWay_final_dataset.xlsx'

sheet_names_map = {
    'delhi_combined_data': 'Delhi',
    'mumbai_combined_data': 'Mumbai',
    'chennai_combined_data': 'Chennai',
    'bengaluru_combined_data': 'Bengaluru',
    'kochi_combined_data': 'Kochi'
}

all_dfs = []

try:
    xls = pd.read_excel(excel_file_path, sheet_name=list(sheet_names_map.keys()))
    for sheet_name, city_name in sheet_names_map.items():
        if sheet_name in xls:
            df = xls[sheet_name]
            df['city'] = city_name
            all_dfs.append(df)
            print(f"Successfully loaded {city_name} data from sheet '{sheet_name}'.")

    if all_dfs:
        combined_df = pd.concat(all_dfs, ignore_index=True)
        print("\nAll datasets combined successfully!")
    else:
        print("\nNo data was loaded. Please check the Excel file and sheet names.")

except FileNotFoundError:
    print(f"Error: '{excel_file_path}' not found. Please make sure you have uploaded the file.")
except Exception as e:
    print(f"An error occurred while reading the Excel file: {e}")
# Out:
# Successfully loaded Delhi data from sheet 'delhi_combined_data'.
# Successfully loaded Mumbai data from sheet 'mumbai_combined_data'.
# Successfully loaded Chennai data from sheet 'chennai_combined_data'.
# Successfully loaded Bengaluru data from sheet 'bengaluru_combined_data'.
# Successfully loaded Kochi data from sheet 'kochi_combined_data'.
#
# All datasets combined successfully!

# %% [markdown]
# ### 3.1. Calculating the Danger Score
#
# We will now calculate a `danger_score` for each area. A **higher score indicates more danger**. This score will be the primary cost for our A* algorithm.

# %%
crime_counts = combined_df.groupby(['city', 'area_name']).size().reset_index(name='crime_count')
area_features = combined_df.groupby(['city', 'area_name']).agg({
    'lighting_quality_score': 'mean',
    'uptime_ratio': 'mean'
}).reset_index()

processed_data = pd.merge(crime_counts, area_features, on=['city', 'area_name'])

def normalize(series):
    if series.max() == series.min():
        return pd.Series(0, index=series.index)
    return (series - series.min()) / (series.max() - series.min())

processed_data['crime_norm'] = processed_data.groupby('city')['crime_count'].transform(normalize)
processed_data['lighting_inverted_norm'] = 1 - processed_data.groupby('city')['lighting_quality_score'].transform(normalize)

crime_weight = 0.7
lighting_weight = 0.3

processed_data['danger_score'] = (crime_weight * processed_data['crime_norm']) + (lighting_weight * processed_data['lighting_inverted_norm'])

processed_data['danger_score'] = 1 + 9 * normalize(processed_data['danger_score'])

print("Danger scores calculated:")
display(processed_data.head())
# Out:
# Danger scores calculated:
#         city     area_name  crime_count  lighting_quality_score  uptime_ratio  \
# 0  Bengaluru    BTM Layout            6                3.166667      0.965126
# 1  Bengaluru  Banashankari            6                3.166667      0.971496
# 2  Bengaluru  Bannerghatta            8                3.625000      0.980795
# 3  Bengaluru  Basavanagudi            7                3.142857      0.972632
# 4  Bengaluru     Bellandur           12                3.083333      0.969095
#
#    crime_norm  lighting_inverted_norm  danger_score
# 0    0.272727                   0.580      4.592074
# 1    0.272727                   0.580      4.592074
# 2    0.454545                   0.195      4.707962
# 3    0.363636                   0.600      5.277557
# 4    0.818182                   0.650      8.557315

# %% [markdown]
# ## 4. Geocoding Area Names

# %%
geolocator = Nominatim(user_agent="safest_route_finder_v6")
coordinates = {}

unique_areas = processed_data[['city', 'area_name']].drop_duplicates()

print("Starting geocoding process... This may take a while.")
for index, row in unique_areas.iterrows():
    city, area = row['city'], row['area_name']
    query = f"{area}, {city}, India"
    try:
        location = geolocator.geocode(query, timeout=10)
        coordinates[(city, area)] = (location.latitude, location.longitude) if location else None
        print(f"Geocoded: {query} -> {coordinates.get((city, area))}")
        time.sleep(1)
    except (GeocoderTimedOut, GeocoderUnavailable):
        print(f"Service timed out for {query}. Retrying...")
        time.sleep(5)
        try:
            location = geolocator.geocode(query, timeout=15)
            coordinates[(city, area)] = (location.latitude, location.longitude) if location else None
        except Exception as e:
            print(f"Could not geocode {query} after retry: {e}")
            coordinates[(city, area)] = None
    except Exception as e:
        print(f"An error occurred for {query}: {e}")
        coordinates[(city, area)] = None

processed_data['coords'] = processed_data.apply(lambda r: coordinates.get((r['city'], r['area_name'])), axis=1)
processed_data.dropna(subset=['coords'], inplace=True)
print(f"\nGeocoding complete.")
# Out:
# Starting geocoding process... This may take a while.
# Geocoded: BTM Layout, Bengaluru, India -> (12.9140008, 77.6102821)
# Geocoded: Banashankari, Bengaluru, India -> (12.9278196, 77.556621)
# Geocoded: Bannerghatta, Bengaluru, India -> (12.9297508, 77.6005147)
# Geocoded: Basavanagudi, Bengaluru, India -> (12.9417261, 77.5755021)
# Geocoded: Bellandur, Bengaluru, India -> (12.9361208, 77.6671843)
# Geocoded: CV Raman Nagar, Bengaluru, India -> (12.9850987, 77.6631173)
# Geocoded: Cooke Town, Bengaluru, India -> (13.0021998, 77.6251814)
# Geocoded: Domlur, Bengaluru, India -> (12.9624669, 77.6381958)
# Geocoded: Electronic City, Bengaluru, India -> (12.8487599, 77.648253)
# Geocoded: Frazer Town, Bengaluru, India -> (12.9975851, 77.6136744)
# Geocoded: Girinagar, Bengaluru, India -> (12.9401439, 77.5444995)
# Geocoded: HSR Layout, Bengaluru, India -> (12.9116225, 77.6388622)
# Geocoded: Hebbal, Bengaluru, India -> (13.0382184, 77.5919)
# Geocoded: Indiranagar, Bengaluru, India -> (12.9732913, 77.6404672)
# Geocoded: JP Nagar, Bengaluru, India -> (12.9096941, 77.5866067)
# Geocoded: Jayanagar, Bengaluru, India -> (12.9292731, 77.5824229)
# Geocoded: KR Puram, Bengaluru, India -> (13.007516, 77.695935)
# Geocoded: Kengeri, Bengaluru, India -> (12.9176571, 77.4837568)
# Geocoded: Koramangala, Bengaluru, India -> (12.9357366, 77.624081)
# Geocoded: Malleshwaram, Bengaluru, India -> (13.0027353, 77.5703253)
# Geocoded: Marathahalli, Bengaluru, India -> (12.9552572, 77.6984163)
# Geocoded: Rajajinagar, Bengaluru, India -> (13.0005359, 77.5496996)
# Geocoded: Sadashivanagar, Bengaluru, India -> (13.0110193, 77.5808641)
# Geocoded: Ulsoor, Bengaluru, India -> (12.9778793, 77.6246697)
# Geocoded: Vijayanagar, Bengaluru, India -> (12.9709537, 77.5373851)
# Geocoded: Whitefield, Bengaluru, India -> (12.9963995, 77.7614229)
# Geocoded: Yelahanka, Bengaluru, India -> (13.1006982, 77.5963454)
# Geocoded: Adyar, Chennai, India -> (13.00645, 80.2577791)
# Geocoded: Aminjikarai, Chennai, India -> (13.0721399, 80.2205453)
# Geocoded: Anna Nagar, Chennai, India -> (13.0872004, 80.2164421)
# Geocoded: Avadi, Chennai, India -> (13.0381702, 80.1347679)
# Geocoded: Ayanavaram, Chennai, India -> (13.0946157, 80.23541)
# Geocoded: Besant Nagar, Chennai, India -> (12.9996907, 80.2682259)
# Geocoded: Egmore, Chennai, India -> (13.0728321, 80.2576906)
# Geocoded: Gopalapuram, Chennai, India -> (13.0497324, 80.2582028)
# Geocoded: Guindy, Chennai, India -> (13.0086685, 80.2126063)
# Geocoded: Iyyappanthangal, Chennai, India -> None
# Geocoded: Kotturpuram, Chennai, India -> (13.0193703, 80.2435512)
# Geocoded: Mambalam, Chennai, India -> (13.0380662, 80.2277752)
# Geocoded: Mylapore, Chennai, India -> (13.0316473, 80.2700166)
# Geocoded: Nungambakkam, Chennai, India -> (13.0620626, 80.240487)
# Geocoded: Perambur, Chennai, India -> (13.1121242, 80.245022)
# Geocoded: Porur, Chennai, India -> (13.0528041, 80.2351811)
# Geocoded: Purasawalkam, Chennai, India -> (13.0893275, 80.2550331)
# Geocoded: Raja Annamalai Puram, Chennai, India -> (13.0244783, 80.253937)
# Geocoded: Royapettah, Chennai, India -> (13.0554718, 80.2639706)
# Geocoded: Sholinganallur, Chennai, India -> (12.9174426, 80.2164902)
# Geocoded: Siruseri, Chennai, India -> (12.8012825, 80.1991871)
# Geocoded: Teynampet, Chennai, India -> (13.0443237, 80.2498455)
# Geocoded: Thiruvanmiyur, Chennai, India -> (12.9858948, 80.2644215)
# Geocoded: Tondiarpet, Chennai, India -> (13.1275202, 80.2819242)
# Geocoded: Vadapalani, Chennai, India -> (13.0509304, 80.2120661)
# Geocoded: Velachery, Chennai, India -> (12.9801655, 80.2228506)
# Geocoded: AIIMS, Delhi, India -> (28.5668602, 77.2078058)
# Geocoded: Adarsh Nagar, Delhi, India -> (28.7165805, 77.1704223)
# Geocoded: Ajmeri Gate, Delhi, India -> (28.6462785, 77.2240315)
# Geocoded: Anand Vihar, Delhi, India -> (28.6468336, 77.3158749)
# Geocoded: Anand Vihar ISBT, Delhi, India -> (28.6467533, 77.3180037)
# Geocoded: Aruna Asaf Ali Marg, Delhi, India -> (28.5206665, 77.1639551)
# Geocoded: Ashok Vihar, Delhi, India -> (28.6885171, 77.1739339)
# Geocoded: Ashram, Delhi, India -> (28.5724231, 77.2585979)
# Geocoded: Aurobindo Marg, Delhi, India -> (28.5756086, 77.2098182)
# Geocoded: Azadpur, Delhi, India -> (28.7057821, 77.1819488)
# Geocoded: Baba Kharak Singh Marg, Delhi, India -> (28.6295914, 77.2124434)
# Geocoded: Babar Road, Delhi, India -> (28.6294483, 77.2324444)
# Geocoded: Badarpur, Delhi, India -> (28.4932633, 77.3030303)
# Geocoded: Baljit Nagar, Delhi, India -> (28.6723046, 77.1084277)
# Geocoded: Ballimaran, Delhi, India -> (28.6531586, 77.2254416)
# Geocoded: Barakhamba Road, Delhi, India -> (28.6300456, 77.2243619)
# Geocoded: Batla House, Delhi, India -> (28.5658436, 77.2857392)
# Geocoded: Bawana, Delhi, India -> (28.79966, 77.0328847)
# Geocoded: Bawana Industrial Area, Delhi, India -> (28.7899827, 77.05343)
# Geocoded: Bengali Market, Delhi, India -> (28.630979, 77.2301167)
# Geocoded: Bhairon Marg, Delhi, India -> (28.6126948, 77.2494221)
# Geocoded: Bhajanpura, Delhi, India -> (28.7009399, 77.2617817)
# Geocoded: Bhishma Pitamah Marg, Delhi, India -> (28.5748155, 77.2292216)
# Geocoded: Bhogal, Delhi, India -> (28.5829056, 77.2487873)
# Geocoded: Burari, Delhi, India -> (28.7536438, 77.2016511)
# Geocoded: CR Park, Delhi, India -> (28.5376883, 77.2516536)
# Geocoded: Chanakyapuri, Delhi, India -> (28.5946775, 77.1885212)
# Geocoded: Chandni Chowk, Delhi, India -> (28.6559834, 77.2321937)
# Geocoded: Chawri Bazar, Delhi, India -> (28.6501803, 77.2294614)
# Geocoded: Chhatarpur, Delhi, India -> (28.5067242, 77.1750019)
# Geocoded: Civil Lines, Delhi, India -> (28.6806862, 77.2225999)
# Geocoded: Connaught Place, Delhi, India -> (28.6314022, 77.2193791)
# Geocoded: Daryaganj, Delhi, India -> (28.64609, 77.243048)
# Geocoded: Defence Colony, Delhi, India -> (28.5713575, 77.2330402)
# Geocoded: Delhi Cantonment, Delhi, India -> (28.5982897, 77.1234689)
# Geocoded: Delhi Cantt Railway Station, Delhi, India -> (28.6117094, 77.1156635)
# Geocoded: Dhaula Kuan, Delhi, India -> (28.5918719, 77.1617158)
# Geocoded: Dilshad Garden, Delhi, India -> (28.6758864, 77.321446)
# Geocoded: Dwarka Flyover, Delhi, India -> (28.5863676, 77.0876311)
# Geocoded: Dwarka Mor, Delhi, India -> (28.61931, 77.0332792)
# Geocoded: Dwarka Sector 1, Delhi, India -> (28.5944933, 77.0734408)
# Geocoded: Dwarka Sector 10, Delhi, India -> (28.5810577, 77.0574996)
# Geocoded: Dwarka Sector 11, Delhi, India -> (28.586443, 77.0494433)
# Geocoded: Dwarka Sector 12, Delhi, India -> (28.5922362, 77.0407315)
# Geocoded: Dwarka Sector 13, Delhi, India -> (28.597009, 77.0335407)
# Geocoded: Dwarka Sector 14, Delhi, India -> (28.6022218, 77.0259765)
# Geocoded: Dwarka Sector 15, Delhi, India -> (28.577813, 77.0582406)
# Geocoded: Dwarka Sector 16, Delhi, India -> (28.577813, 77.0582406)
# Geocoded: Dwarka Sector 17, Delhi, India -> (28.5896931, 77.0263553)
# Geocoded: Dwarka Sector 18, Delhi, India -> (28.5696878, 77.0643221)
# Geocoded: Dwarka Sector 19, Delhi, India -> (28.5649787, 77.0510412)
# Geocoded: Dwarka Sector 2, Delhi, India -> (28.5918607, 77.045254)
# Geocoded: Dwarka Sector 20, Delhi, India -> (28.577813, 77.0582406)
# Geocoded: Dwarka Sector 21, Delhi, India -> (28.5519218, 77.0585605)
# Geocoded: Dwarka Sector 22, Delhi, India -> (28.5541847, 77.0529077)
# Geocoded: Dwarka Sector 23, Delhi, India -> (28.577813, 77.0582406)
# Geocoded: Dwarka Sector 3, Delhi, India -> (28.6130743, 77.0336395)
# Geocoded: Dwarka Sector 4, Delhi, India -> (28.5923128, 77.0451892)
# Geocoded: Dwarka Sector 5, Delhi, India -> (28.5924315, 77.0450391)
# Geocoded: Dwarka Sector 6, Delhi, India -> (28.5973447, 77.0648046)
# Geocoded: Dwarka Sector 7, Delhi, India -> (28.5861818, 77.0711318)
# Geocoded: Dwarka Sector 8, Delhi, India -> (28.5656109, 77.0670366)
# Geocoded: Dwarka Sector 9, Delhi, India -> (28.574272, 77.0653316)
# Geocoded: East Patel Nagar, Delhi, India -> (28.645649, 77.1725666)
# Geocoded: East of Kailash, Delhi, India -> (28.5570322, 77.2446139)
# Geocoded: Fatehpuri, Delhi, India -> (28.6566423, 77.222633)
# Geocoded: GT Karnal Road, Delhi, India -> (28.7005779, 77.181923)
# Geocoded: GTB Nagar, Delhi, India -> (28.6981333, 77.2063998)
# Geocoded: Gandhi Nagar, Delhi, India -> (28.6587904, 77.2715878)
# Geocoded: Geeta Colony, Delhi, India -> (28.6510892, 77.2749996)
# Geocoded: Golf Links, Delhi, India -> (28.5959698, 77.2311628)
# Geocoded: Greater Kailash 1, Delhi, India -> (28.5538933, 77.2400488)
# Geocoded: Greater Kailash 2, Delhi, India -> (28.5500342, 77.2338932)
# Geocoded: Green Park, Delhi, India -> (28.5564421, 77.2038699)
# Geocoded: Hauz Khas, Delhi, India -> (28.5498087, 77.2077638)
# Geocoded: Hazrat Nizamuddin Railway Station, Delhi, India -> (28.5864131, 77.2529822)
# Geocoded: I.P. Estate, Delhi, India -> None
# Geocoded: IGI Airport T3, Delhi, India -> (28.5526892, 77.1046781)
# Geocoded: IIT Delhi, Delhi, India -> (28.5449971, 77.1891506)
# Geocoded: INA Colony, Delhi, India -> (28.5774481, 77.212578)
# Geocoded: IP Extension, Delhi, India -> (28.6319012, 77.3107328)
# Geocoded: ITO, Delhi, India -> (28.6281909, 77.2410437)
# Geocoded: Inderlok, Delhi, India -> (28.6727066, 77.1691872)
# Geocoded: Jafrabad, Delhi, India -> (28.6865368, 77.2763793)
# Geocoded: Jahangirpuri, Delhi, India -> (28.7259717, 77.162658)
# Geocoded: Janakpuri, Delhi, India -> (28.6219272, 77.0874757)
# Geocoded: Janakpuri District Centre, Delhi, India -> (28.6326959, 77.0809844)
# Geocoded: Jangpura Extension, Delhi, India -> (28.5821286, 77.2434423)
# Geocoded: Janpath, Delhi, India -> (28.6240485, 77.2192587)
# Geocoded: Jasola, Delhi, India -> (28.5427353, 77.2913342)
# Geocoded: Josef Tito Marg, Delhi, India -> None
# Geocoded: Jungpura, Delhi, India -> None
# Geocoded: Kalindi Kunj Road, Delhi, India -> (28.5620981, 77.2923265)
# Geocoded: Kalkaji, Delhi, India -> (28.5469476, 77.258801)
# Geocoded: Kamla Nagar, Delhi, India -> (28.6806752, 77.2039504)
# Geocoded: Kanhaiya Nagar, Delhi, India -> (28.6824082, 77.1647754)
# Geocoded: Karkardooma, Delhi, India -> (28.6493107, 77.2962918)
# Geocoded: Karol Bagh, Delhi, India -> (28.6529982, 77.1890227)
# Geocoded: Kashmere Gate, Delhi, India -> (28.6668141, 77.2290549)
# Geocoded: Kashmere Gate ISBT, Delhi, India -> (28.6686963, 77.2304228)
# Geocoded: Katra Neel, Delhi, India -> (28.6576399, 77.2258081)
# Geocoded: Khan Market, Delhi, India -> (28.5995141, 77.2259785)
# Geocoded: Khel Gaon, Delhi, India -> (28.6059774, 77.2748841)
# Geocoded: Kirti Nagar, Delhi, India -> (28.655746, 77.1506635)
# Geocoded: Krishna Nagar, Delhi, India -> (28.6578127, 77.2901199)
# Geocoded: Kucha Mahajani, Delhi, India -> None
# Geocoded: Lajpat Nagar, Delhi, India -> (28.5660924, 77.2432851)
# Geocoded: Lal Kuan, Delhi, India -> (28.5026215, 77.2845419)
# Geocoded: Laxmi Nagar, Delhi, India -> (28.6305974, 77.277523)
# Geocoded: Lodhi Road, Delhi, India -> (28.5911424, 77.2291452)
# Geocoded: Lodi Colony, Delhi, India -> (28.586203, 77.2268576)
# Geocoded: Mahipalpur, Delhi, India -> (28.544537, 77.1279229)
# Geocoded: Majnu Ka Tilla, Delhi, India -> (28.704335, 77.224494)
# Geocoded: Malviya Nagar, Delhi, India -> (28.5339201, 77.2124474)
# Geocoded: Mandawali, Delhi, India -> (28.628772, 77.2939554)
# Geocoded: Mandir Marg, Delhi, India -> (28.6383914, 77.2033216)
# Geocoded: Mangolpuri, Delhi, India -> (28.6873187, 77.0960253)
# Geocoded: Mathura Road, Delhi, India -> (28.5083159, 77.2994628)
# Geocoded: Matia Mahal, Delhi, India -> (28.647591, 77.2352178)
# Geocoded: Mayapuri Industrial Area, Delhi, India -> (28.6305879, 77.129781)
# Geocoded: Mayur Vihar Phase 1, Delhi, India -> (28.6035543, 77.2899208)
# Geocoded: Mayur Vihar Phase 2, Delhi, India -> (28.6185752, 77.3013137)
# Geocoded: Mayur Vihar Phase 3, Delhi, India -> (28.6018747, 77.3259814)
# Geocoded: Mayur Vihar Pocket 1, Delhi, India -> (28.6055975, 77.2975219)
# Geocoded: Mayur Vihar Pocket 2, Delhi, India -> (28.6098555, 77.2926318)
# Geocoded: Mayur Vihar Pocket 3, Delhi, India -> (28.6054841, 77.2980247)
# Geocoded: Meera Bagh, Delhi, India -> (28.658844, 77.0908475)
# Geocoded: Mehrauli, Delhi, India -> (28.5218262, 77.1783232)
# Geocoded: Minto Road, Delhi, India -> (28.6381228, 77.2236277)
# Geocoded: Model Town, Delhi, India -> (28.707334, 77.1885231)
# Geocoded: Model Town 1, Delhi, India -> (28.707334, 77.1885231)
# Geocoded: Model Town 2, Delhi, India -> (28.707334, 77.1885231)
# Geocoded: Model Town 3, Delhi, India -> (28.707334, 77.1885231)
# Geocoded: Moti Nagar, Delhi, India -> (28.657859, 77.1424288)
# Geocoded: Mukherjee Nagar, Delhi, India -> (28.7125567, 77.2144044)
# Geocoded: Mundka, Delhi, India -> (28.6819261, 77.0308105)
# Geocoded: NH 48 (Delhi-Gurgaon), Delhi, India -> (28.5338922, 77.0899378)
# Geocoded: Najafgarh, Delhi, India -> (28.6124504, 76.9865067)
# Geocoded: Nangloi, Delhi, India -> (28.6862813, 77.0573608)
# Geocoded: Narela, Delhi, India -> (28.8464766, 77.0856631)
# Geocoded: Nehru Place, Delhi, India -> (28.5492574, 77.2529526)
# Geocoded: Nelson Mandela Marg, Delhi, India -> (28.5312216, 77.1496967)
# Geocoded: Nelson Mandela Road, Delhi, India -> None
# Geocoded: New Delhi Railway Station, Delhi, India -> (28.6402816, 77.2204103)
# Geocoded: New Friends Colony, Delhi, India -> (28.5671008, 77.2697643)
# Geocoded: Nizamuddin East, Delhi, India -> (28.5896671, 77.2503854)
# Geocoded: Nizamuddin West, Delhi, India -> (28.588365, 77.2449546)
# Geocoded: Noida Link Road, Delhi, India -> (28.590882, 77.2956727)
# Geocoded: Noida Sector 15 Metro Road, Delhi, India -> None
# Geocoded: Okhla Bird Sanctuary Road, Delhi, India -> None
# Geocoded: Okhla Industrial Area, Delhi, India -> (28.5475409, 77.2828271)
# Geocoded: Okhla Phase 1, Delhi, India -> (28.5203651, 77.2776273)
# Geocoded: Okhla Phase 2, Delhi, India -> (28.5370513, 77.2703851)
# Geocoded: Okhla Phase 3, Delhi, India -> (28.5636616, 77.2890546)
# Geocoded: Old Delhi Railway Station, Delhi, India -> (28.660932, 77.2276494)
# Geocoded: Old Rajinder Nagar, Delhi, India -> None
# Geocoded: Outer Ring Road, Delhi, India -> (28.5510382, 77.1833844)
# Geocoded: Outer Ring Road Pitampura Stretch, Delhi, India -> None
# Geocoded: PVR Anupam Saket, Delhi, India -> None
# Geocoded: Paharganj, Delhi, India -> (28.6414989, 77.2140607)
# Geocoded: Palam, Delhi, India -> (28.5918933, 77.0828242)
# Geocoded: Pandav Nagar, Delhi, India -> (28.619553, 77.2830355)
# Geocoded: Paschim Vihar, Delhi, India -> (28.6695782, 77.095956)
# Geocoded: Paschim Vihar East, Delhi, India -> (28.6773563, 77.1122823)
# Geocoded: Paschim Vihar West, Delhi, India -> (28.67852, 77.0997686)
# Geocoded: Patel Nagar, Delhi, India -> (28.6450127, 77.1692817)
# Geocoded: Patparganj, Delhi, India -> (28.6115923, 77.2905644)
# Geocoded: Peeragarhi, Delhi, India -> (28.6773142, 77.0931024)
# Geocoded: Pitampura, Delhi, India -> (28.6995123, 77.1301047)
# Geocoded: Pitampura CU Block, Delhi, India -> None
# Geocoded: Pitampura KD Block, Delhi, India -> None
# Geocoded: Pitampura ND Block, Delhi, India -> None
# Geocoded: Pitampura RD Block, Delhi, India -> None
# Geocoded: Pragati Maidan, Delhi, India -> (28.6172378, 77.2434616)
# Geocoded: Preet Vihar, Delhi, India -> (28.6414176, 77.2952819)
# Geocoded: Punjabi Bagh, Delhi, India -> (28.672995, 77.1461239)
# Geocoded: Qutub Institutional Area, Delhi, India -> (28.5398146, 77.1840572)
# Geocoded: RK Puram, Delhi, India -> (28.5656918, 77.174646)
# Geocoded: Rajender Nagar, Delhi, India -> None
# Geocoded: Rajouri Garden, Delhi, India -> (28.6511896, 77.1242597)
# Geocoded: Ram Nagar, Delhi, India -> (28.6789863, 77.2967005)
# Geocoded: Ramesh Nagar, Delhi, India -> (28.6527444, 77.1316496)
# Geocoded: Ring Road, Delhi, India -> (28.6390447, 77.1295777)
# Geocoded: Ring Road Ashram Stretch, Delhi, India -> None
# Geocoded: Rohini Sector 1, Delhi, India -> (28.7373427, 77.1097184)
# Geocoded: Rohini Sector 10, Delhi, India -> (28.7194201, 77.1096302)
# Geocoded: Rohini Sector 12, Delhi, India -> (28.7313339, 77.1158944)
# Geocoded: Rohini Sector 14, Delhi, India -> (28.7067328, 77.1268498)
# Geocoded: Rohini Sector 15, Delhi, India -> (28.7213514, 77.136613)
# Geocoded: Rohini Sector 16, Delhi, India -> (28.7349627, 77.1146848)
# Geocoded: Rohini Sector 17, Delhi, India -> (28.7342799, 77.1135027)
# Geocoded: Rohini Sector 19, Delhi, India -> (28.7413557, 77.1323967)
# Geocoded: Rohini Sector 2, Delhi, India -> (28.7083604, 77.1243019)
# Geocoded: Rohini Sector 20, Delhi, India -> (28.7371777, 77.1104703)
# Geocoded: Rohini Sector 21, Delhi, India -> (28.7352869, 77.1099856)
# Geocoded: Rohini Sector 22, Delhi, India -> (28.7192546, 77.0652677)
# Geocoded: Rohini Sector 23, Delhi, India -> (28.7326849, 77.0884608)
# Geocoded: Rohini Sector 25, Delhi, India -> (28.7368198, 77.1104315)
# Geocoded: Rohini Sector 26, Delhi, India -> (28.7354588, 77.1099316)
# Geocoded: Rohini Sector 27, Delhi, India -> (28.7474738, 77.1194361)
# Geocoded: Rohini Sector 4, Delhi, India -> (28.7348409, 77.1097878)
# Geocoded: Rohini Sector 5, Delhi, India -> (28.7356257, 77.1111052)
# Geocoded: Rohini Sector 6, Delhi, India -> (28.7375874, 77.1100185)
# Geocoded: Rohini Sector 8, Delhi, India -> (28.7357991, 77.1120982)
# Geocoded: Rohtak Road, Delhi, India -> (28.6816281, 77.0764336)
# Geocoded: Sadar Bazaar, Delhi, India -> (28.658087, 77.2170087)
# Geocoded: Safdarjung Enclave, Delhi, India -> (28.56502, 77.1925584)
# Geocoded: Sainik Farms, Delhi, India -> (28.5067758, 77.21857)
# Geocoded: Saket, Delhi, India -> (28.521168, 77.2022237)
# Geocoded: Sangam Vihar, Delhi, India -> (28.5057128, 77.2484672)
# Geocoded: Sarai Kale Khan, Delhi, India -> (28.5866263, 77.2562282)
# Geocoded: Sarai Rohilla, Delhi, India -> (28.6644729, 77.1838135)
# Geocoded: Sardar Patel Marg, Delhi, India -> (28.6037626, 77.1842489)
# Geocoded: Sarita Vihar, Delhi, India -> (28.5334785, 77.2935232)
# Geocoded: Sarojini Nagar, Delhi, India -> (28.575817, 77.1980786)
# Geocoded: Seelampur, Delhi, India -> (28.6698165, 77.2668137)
# Geocoded: Seemapuri, Delhi, India -> (28.6807082, 77.3277509)
# Geocoded: Shahdara, Delhi, India -> (28.6758661, 77.2985078)
# Geocoded: Shalimar Bagh, Delhi, India -> (28.7019574, 77.1654317)
# Geocoded: Shalimar Bagh A Block, Delhi, India -> None
# Geocoded: Shalimar Bagh B Block, Delhi, India -> None
# Geocoded: Shalimar Bagh C Block, Delhi, India -> None
# Geocoded: Sheikh Sarai, Delhi, India -> (28.5368964, 77.2222387)
# Geocoded: Sita Ram Bazar, Delhi, India -> (28.6499077, 77.2261794)
# Geocoded: Sonia Vihar, Delhi, India -> (28.7199257, 77.2481823)
# Geocoded: South Extension 1, Delhi, India -> (28.5696545, 77.2390985)
# Geocoded: South Extension 2, Delhi, India -> (28.5681089, 77.2221923)
# Geocoded: Sri Aurobindo Marg, Delhi, India -> (28.5396291, 77.2000301)
# Geocoded: Subhash Nagar, Delhi, India -> (28.6404593, 77.1051815)
# Geocoded: Sunder Nagar, Delhi, India -> (28.6016454, 77.2421181)
# Geocoded: Sunder Nagar Market, Delhi, India -> (28.6018973, 77.2411194)
# Geocoded: Tagore Garden, Delhi, India -> (28.6437639, 77.1128454)
# Geocoded: Tilak Nagar, Delhi, India -> (28.6365265, 77.096482)
# Geocoded: Tolstoy Road, Delhi, India -> None
# Geocoded: Trilokpuri, Delhi, India -> (28.6056473, 77.3066482)
# Geocoded: Tughlakabad, Delhi, India -> (28.5034421, 77.2970508)
# Geocoded: Tughlaqabad Extension, Delhi, India -> None
# Geocoded: Turkman Gate, Delhi, India -> (28.6422769, 77.232677)
# Geocoded: Uttam Nagar, Delhi, India -> (28.6215226, 77.0611064)
# Geocoded: Vasant Kunj, Delhi, India -> (28.5292495, 77.1541335)
# Geocoded: Vasant Vihar, Delhi, India -> (28.557827, 77.1611168)
# Geocoded: Vikaspuri, Delhi, India -> (28.638643, 77.0731382)
# Geocoded: Vikaspuri Extension, Delhi, India -> (28.6433241, 77.0843916)
# Geocoded: Vivek Vihar, Delhi, India -> (28.6691641, 77.312267)
# Geocoded: Wazirabad, Delhi, India -> (28.7297608, 77.2212803)
# Geocoded: Wazirabad Road, Delhi, India -> (28.6982308, 77.3197172)
# Geocoded: Welcome, Delhi, India -> (28.6724018, 77.2770239)
# Geocoded: West Patel Nagar, Delhi, India -> (28.6519279, 77.162923)
# Geocoded: Yamuna Vihar, Delhi, India -> (28.700372, 77.2727728)
# Geocoded: Zakir Nagar, Delhi, India -> (28.5673956, 77.2806319)
# Geocoded: Aluva, Kochi, India -> (10.1100952, 76.3495159)
# Geocoded: Angamaly, Kochi, India -> (10.1752188, 76.3751158)
# Geocoded: Cherai, Kochi, India -> (10.1406994, 76.1935753)
# Geocoded: Edappally, Kochi, India -> (10.025487, 76.3079848)
# Geocoded: Fort Kochi, Kochi, India -> (9.967569, 76.2421901)
# Geocoded: Kakkanad, Kochi, India -> (10.0069969, 76.3436869)
# Geocoded: Kalamassery, Kochi, India -> (10.0585393, 76.3221673)
# Geocoded: Kaloor, Kochi, India -> (9.9966421, 76.2861695)
# Geocoded: MG Road, Kochi, India -> (9.9824891, 76.2829173)
# Geocoded: Maradu, Kochi, India -> (9.9451454, 76.3342475)
# Geocoded: Marine Drive, Kochi, India -> None
# Geocoded: Mattancherry, Kochi, India -> (9.9589134, 76.2588346)
# Geocoded: Palarivattom, Kochi, India -> (10.0003739, 76.3120698)
# Geocoded: Panampilly Nagar, Kochi, India -> (9.9627979, 76.2943869)
# Geocoded: Paravur, Kochi, India -> (10.1436624, 76.2278555)
# Geocoded: Thevara, Kochi, India -> (9.944643, 76.2947828)
# Geocoded: Thrikkakkara, Kochi, India -> (10.0331047, 76.3146028)
# Geocoded: Thripunithura, Kochi, India -> None
# Geocoded: Vyttila, Kochi, India -> (9.9651009, 76.3187314)
# Geocoded: Willingdon Island, Kochi, India -> (9.9480419, 76.2753943)
# Geocoded: Andheri, Mumbai, India -> (19.1196976, 72.8464205)
# Geocoded: Antop Hill, Mumbai, India -> (19.0207608, 72.8652556)
# Geocoded: Bandra, Mumbai, India -> (19.0549792, 72.8402203)
# Geocoded: Bhandup, Mumbai, India -> (19.1438684, 72.9384327)
# Geocoded: Bhuleshwar, Mumbai, India -> (18.9537706, 72.8274755)
# Geocoded: Borivali, Mumbai, India -> (19.229068, 72.8573628)
# Geocoded: Byculla, Mumbai, India -> (18.9766219, 72.8327936)
# Geocoded: Chembur, Mumbai, India -> (19.054818, 72.8979713)
# Geocoded: Colaba, Mumbai, India -> (18.915091, 72.8259691)
# Geocoded: Dadar, Mumbai, India -> (19.0192269, 72.8428479)
# Geocoded: Dahisar, Mumbai, India -> (19.2493572, 72.8596302)
# Geocoded: Fort, Mumbai, India -> (18.9332665, 72.8345146)
# Geocoded: Ghatkopar, Mumbai, India -> (19.0856928, 72.9083668)
# Geocoded: Girgaon, Mumbai, India -> (18.9521477, 72.8220576)
# Geocoded: Goregaon, Mumbai, India -> (19.1648688, 72.8495492)
# Geocoded: Govandi, Mumbai, India -> (19.0553688, 72.9150702)
# Geocoded: Jogeshwari, Mumbai, India -> (19.1348994, 72.8488199)
# Geocoded: Kalbadevi, Mumbai, India -> (18.9492575, 72.8279382)
# Geocoded: Kamathipura, Mumbai, India -> (18.9653224, 72.8264349)
# Geocoded: Kandivali, Mumbai, India -> (19.2041136, 72.8517376)
# Geocoded: Khar, Mumbai, India -> (19.0682411, 72.8400412)
# Geocoded: Kurla, Mumbai, India -> (19.0655397, 72.8795636)
# Geocoded: Malabar Hill, Mumbai, India -> (18.9581616, 72.8033665)
# Geocoded: Malad, Mumbai, India -> (19.1867193, 72.8485884)
# Geocoded: Mankhurd, Mumbai, India -> (19.0485178, 72.9323356)
# Geocoded: Matunga, Mumbai, India -> (19.0274356, 72.8501467)
# Geocoded: Mulund, Mumbai, India -> (19.1721762, 72.9562383)
# Geocoded: Parel, Mumbai, India -> (19.0094817, 72.8376614)
# Geocoded: Powai, Mumbai, India -> (19.1187195, 72.9073476)
# Geocoded: Santacruz, Mumbai, India -> (19.0789383, 72.8446344)
# Geocoded: Sion, Mumbai, India -> (19.0465213, 72.8632834)
# Geocoded: Tardeo, Mumbai, India -> (18.9645237, 72.8209188)
# Geocoded: Trombay, Mumbai, India -> (19.033651, 72.9503637)
# Geocoded: Vidyavihar, Mumbai, India -> (19.0795422, 72.8971169)
# Geocoded: Vikhroli, Mumbai, India -> (19.1114795, 72.928021)
# Geocoded: Vile Parle, Mumbai, India -> (19.0999098, 72.8440038)
# Geocoded: Wadala, Mumbai, India -> (19.0269192, 72.8759337)
# Geocoded: Worli, Mumbai, India -> (18.9988404, 72.8170327)
#
# Geocoding complete.

# %% [markdown]
# ## 5. Graph Creation and A* Algorithm

# %% [markdown]
# ### 5.1. Haversine Distance Function

# %%
def haversine_distance(coord1, coord2):
    """Calculate the distance between two lat/lon points in kilometers."""
    R = 6371.0
    lat1, lon1 = map(radians, coord1)
    lat2, lon2 = map(radians, coord2)
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2)**2 + cos(lat1) * cos(lat2) * sin(dlon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    return R * c

# %% [markdown]
# ### 5.2. A* Algorithm (Optimized for Safety)

# %%
def a_star_search(graph, start_node, end_node, coords_map, danger_scores):
    open_set = []
    # Heap stores (f_score, g_score, node)
    # g_score is the cumulative danger score
    heapq.heappush(open_set, (0, 0, start_node))

    came_from = {}
    g_score = {node: float('inf') for node in graph.nodes}
    g_score[start_node] = 0

    f_score = {node: float('inf') for node in graph.nodes}
    # Initial f_score is just the heuristic from the start
    f_score[start_node] = haversine_distance(coords_map[start_node], coords_map[end_node])

    while open_set:
        _, current_g, current_node = heapq.heappop(open_set)

        if current_node == end_node:
            path = []
            while current_node in came_from:
                path.append(current_node)
                current_node = came_from[current_node]
            path.append(start_node)
            return path[::-1]

        for neighbor in graph.neighbors(current_node):
            # g(n) is the cumulative danger score
            tentative_g_score = current_g + danger_scores[neighbor]

            if tentative_g_score < g_score[neighbor]:
                came_from[neighbor] = current_node
                g_score[neighbor] = tentative_g_score

                # h(n) is the distance heuristic
                heuristic = haversine_distance(coords_map[neighbor], coords_map[end_node])

                f_score[neighbor] = tentative_g_score + heuristic
                heapq.heappush(open_set, (f_score[neighbor], tentative_g_score, neighbor))

    return None

# %% [markdown]
# ### 5.3. Building the City Graphs

# %%
city_graphs = {}
city_coords = {}
city_danger_scores = {}

for city in processed_data['city'].unique():
    G = nx.Graph()
    city_df = processed_data[processed_data['city'] == city]
    nodes = city_df['area_name'].tolist()
    G.add_nodes_from(nodes)

    # Create a fully connected graph for each city
    for i in range(len(nodes)):
        for j in range(i + 1, len(nodes)):
            G.add_edge(nodes[i], nodes[j])

    city_graphs[city] = G
    city_coords[city] = pd.Series(city_df.coords.values, index=city_df.area_name).to_dict()
    city_danger_scores[city] = pd.Series(city_df.danger_score.values, index=city_df.area_name).to_dict()

print("Graphs for all cities have been created.")
# Out:
# Graphs for all cities have been created.

# %% [markdown]
# ## 6. Visualization with Folium

# %%
def plot_safest_route(city, path, coords_map, danger_scores):
    if not path:
        print("No path found to display.")
        return

    avg_lat = np.mean([coords_map[loc][0] for loc in path])
    avg_lon = np.mean([coords_map[loc][1] for loc in path])

    m = folium.Map(location=[avg_lat, avg_lon], zoom_start=12)

    # Add markers for all locations in the city
    for area, coord in coords_map.items():
        score = danger_scores.get(area, 'N/A')
        folium.Marker(
            location=coord,
            popup=f"{area}<br>Danger Score: {score:.2f}",
            icon=folium.Icon(color='gray', icon='info-sign')
        ).add_to(m)

    path_coords = [coords_map[loc] for loc in path]

    # Highlight path nodes and draw the route
    folium.Marker(location=path_coords[0], popup=f"START: {path[0]}", icon=folium.Icon(color='green', icon='play')).add_to(m)
    folium.Marker(location=path_coords[-1], popup=f"END: {path[-1]}", icon=folium.Icon(color='red', icon='stop')).add_to(m)

    for i in range(1, len(path) - 1):
        folium.Marker(
            location=path_coords[i],
            popup=f"HOP: {path[i]}<br>Danger Score: {danger_scores.get(path[i]):.2f}",
            icon=folium.Icon(color='blue', icon='circle')
        ).add_to(m)

    # Draw the line connecting all the hops
    folium.PolyLine(path_coords, color='purple', weight=3, opacity=0.8).add_to(m)

    return m

# %% [markdown]
# ## 7. Interactive Route Finder

# %%
# --- Widgets --- #
city_dropdown = widgets.Dropdown(options=sorted(processed_data['city'].unique()), description='City:')
start_dropdown = widgets.Dropdown(description='Start:')
end_dropdown = widgets.Dropdown(description='End:')
find_button = widgets.Button(description="Find Safest Route")
output_area = widgets.Output()

# --- Logic --- #
def update_locations(change):
    selected_city = change['new']
    locations = sorted(processed_data[processed_data['city'] == selected_city]['area_name'].unique())
    start_dropdown.options = locations
    end_dropdown.options = locations

def on_button_clicked(b):
    with output_area:
        clear_output(wait=True)
        city, start, end = city_dropdown.value, start_dropdown.value, end_dropdown.value

        if not all([city, start, end]):
            print("Please select a city, start, and end location.")
            return
        if start == end:
            print("Start and end locations cannot be the same.")
            return

        print(f"Finding the safest route from {start} to {end} in {city}...")

        graph, coords, scores = city_graphs[city], city_coords[city], city_danger_scores[city]

        # The danger weight slider is removed, so the function is called without it.
        path = a_star_search(graph, start, end, coords, scores)

        if path:
            total_dist = 0
            for i in range(len(path) - 1):
                total_dist += haversine_distance(coords[path[i]], coords[path[i+1]])

            total_danger = sum([scores[node] for node in path])

            print(f"\nSafest path found with intermediate hops:")
            print(f"{' -> '.join(path)}")
            print(f"\nTotal Route Distance: {total_dist:.2f} km")
            print(f"Total Danger Score: {total_danger:.2f}")

            route_map = plot_safest_route(city, path, coords, scores)
            display(route_map)
        else:
            print("Could not find a path.")

# --- Observers --- #
city_dropdown.observe(update_locations, names='value')
find_button.on_click(on_button_clicked)

update_locations({'new': city_dropdown.value})

# --- Display --- #
display(widgets.VBox([
    city_dropdown,
    start_dropdown,
    end_dropdown,
    find_button,
    output_area
]))
# Out:
# VBox(children=(Dropdown(description='City:', options=('Bengaluru', 'Chennai', 'Delhi', 'Kochi', 'Mumbai'), val…

# %%
# !pip install polyline


import requests
import polyline
import folium
import numpy as np

def get_osrm_route(coords_sequence):
    waypoints = [f"{lon},{lat}" for lat, lon in coords_sequence]
    coords_str = ";".join(waypoints)
    url = f"http://router.project-osrm.org/route/v1/driving/{coords_str}"
    params = {
        "overview": "full",
        "geometries": "polyline"
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        route_polyline = data['routes'][0]['geometry']
        return polyline.decode(route_polyline)
    else:
        print(f"OSRM error: {response.status_code}")
        return None

def plot_osrm_route(city, path, coords_map, danger_scores):
    if not path:
        print("No path found to display.")
        return

    avg_lat = np.mean([coords_map[loc][0] for loc in path])
    avg_lon = np.mean([coords_map[loc][1] for loc in path])

    m = folium.Map(location=[avg_lat, avg_lon], zoom_start=12)

    # All nodes in city
    for area, coord in coords_map.items():
        score = danger_scores.get(area, 'N/A')
        if score != 'N/A':
            if score < 3.5:
                color = "green"
            elif score < 6:
                color = "orange"
            else:
                color = "red"
        else:
            color = "gray"
        folium.CircleMarker(
            location=coord,
            radius=5,
            popup=f"{area}<br>Danger Score: {score:.2f}",
            color=color,
            fill=True,
            fill_opacity=0.7
        ).add_to(m)

    # Mark start and end
    folium.Marker(location=coords_map[path[0]], popup=f"START: {path[0]}", icon=folium.Icon(color='green', icon='play')).add_to(m)
    folium.Marker(location=coords_map[path[-1]], popup=f"END: {path[-1]}", icon=folium.Icon(color='red', icon='stop')).add_to(m)

    # OSRM route based on path coords
    path_coords = [coords_map[loc] for loc in path]
    osrm_route = get_osrm_route(path_coords)
    if osrm_route:
        folium.PolyLine(osrm_route, color='green', weight=7, opacity=0.9, dash_array="10,8").add_to(m)
    else:
        folium.PolyLine(path_coords, color='purple', weight=3, opacity=0.8).add_to(m)

    return m

# Modify your existing button callback to use this plotting

def on_button_clicked(b):
    with output_area:
        clear_output(wait=True)
        city, start, end = city_dropdown.value, start_dropdown.value, end_dropdown.value

        if not all([city, start, end]):
            print("Please select a city, start, and end location.")
            return
        if start == end:
            print("Start and end locations cannot be the same.")
            return

        print(f"Finding the safest route from {start} to {end} in {city}...")

        graph, coords, scores = city_graphs[city], city_coords[city], city_danger_scores[city]

        path = a_star_search(graph, start, end, coords, scores)

        if path:
            total_dist = 0
            for i in range(len(path) - 1):
                from_coord, to_coord = coords[path[i]], coords[path[i + 1]]
                # sum distances along the path (optional)
                # you can also compute total danger or other metrics here

            print(f"\nSafest path found with intermediate hops:")
            print(" -> ".join(path))

            # Plot with OSRM route on folium
            route_map = plot_osrm_route(city, path, coords, scores)

            map_filename = 'safest_route.html'
            route_map.save(map_filename)
            print(f"\nMap has been saved as '{map_filename}'. Please open it to view the route.")

            display(route_map)
        else:
            print("Could not find a path. Try different locations.")

# Attach modified callback
find_button.on_click(on_button_clicked)
# Out:
# Requirement already satisfied: polyline in /usr/local/lib/python3.12/dist-packages (2.0.3)
